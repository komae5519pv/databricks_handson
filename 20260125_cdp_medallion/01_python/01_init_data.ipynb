# %% [markdown]
# # サンプルデータ準備
# - サーバレスコンピュートで実行してください
#
# #### TODO
# - サンプルデータを自動生成(約5分) or 既存CSVをGithubからダウンロード(数秒)します

# %%
# %run ./00_config

# %% [markdown]
# ### サンプルデータを自動生成(約5分)
# こちらを実行する場合、次のセルのコメントアウトをはずしてください<br>
# こちらを実行しない場合、次のセルをコメントアウトしてください<br>

# %%
# %run ./_helper/generate_data $MY_CATALOG=MY_CATALOG $MY_SCHEMA=MY_SCHEMA $MY_VOLUME=MY_VOLUME

# %% [markdown]
# ### 既存CSVをGithubからダウンロード(数秒)
# こちらを実行する場合、次のセルのコメントアウトをはずしてください<br>
# こちらを実行しない場合、次のセルをコメントアウトしてください<br>

# %%
# %run ./_helper/load_data $MY_CATALOG=MY_CATALOG $MY_SCHEMA=MY_SCHEMA $MY_VOLUME=MY_VOLUME
